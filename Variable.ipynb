# %% [markdown]
# Variable In Python

# %%
x = 13
print(x)
# Out:
# 13

# %%
type(x)
# Out:
# int

# %%
y= 'Mint Chocolate Chip'
print(y)
# Out:
# Mint Chocolate Chip

# %%
type(y)
# Out:
# str

# %%
x,y,z ='chocolate','vanila','rocky road'

print(x)
print(y)
print(z)
# Out:
# chocolate
# vanila
# rocky road

# %%
ice_cream =['chocolate','vanila','rocky road']

x,y,z = ice_cream
print(ice_cream)
print(x)
print(y)
print(z)
type(ice_cream)
# Out:
# ['chocolate', 'vanila', 'rocky road']
# vanila
# rocky road
# list

# %%
#Camel Case
# Test Variable Case

testVariableCase = 'Vanila Swirl'

# %%
#Pascal Case
# Test Variable Case

TestVariableCase = 'Vanila Swirl'

# %%
#Snake Case
# Test Variable Case

test_variable_case = 'Vanila Swirl'

# %%
x = 'Ice Cream '
y = 'is '
z = 'my favorite'
print(x+y+z)
# Out:
# Ice Cream is my favorite
