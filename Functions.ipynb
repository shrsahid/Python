# %% [markdown]
# Functions

# %%
def first_func():
    print('We did it!')
first_func()
# Out:
# We did it!

# %%
def num_squared(num):
    print(num**2)
num_squared(5)
# Out:
# 25

# %%
def num_squared_cust(num,power):
    print(num**power)
num_squared(5,3)
# Out:
# 125

# %%
args_tuple=(5,4,1,2,8)

def num_args(*num):
    print(num[0]*num[1])
num_args(*args_tuple)
# Out:
# 20

# %%
def num_squared_cust(num,power):
    print(num**power)
num_squared(power=5,num=3)
# Out:
# 243

# %%
def num_kwarg(**num):
    print('My number is : '+ num['integer'])

num_kwarg(integer='2039')
# Out:
# My number is : 2039
